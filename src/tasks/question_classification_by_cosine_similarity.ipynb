# %%
## Import packages and Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
from nltk.corpus import stopwords
from nltk import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import string

import io
import re
import nltk

import spacy
# Download the stopwords corpus if not already downloaded
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')


# Load the spaCy English language model
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
## load the dataset
df = pd.read_csv('/content/Health Care Service - Sheet1.csv')

# %%
df.head()
# Out:
#    S.No.               Topic Job Role Collaborator's Name  \
# 0    1.0  Nursing Assistants    Nurse           Sneha G S
# 1    2.0  Nursing Assistants    Nurse           Sneha G S
# 2    3.0  Nursing Assistants    Nurse           Sneha G S
# 3    4.0  Nursing Assistants    Nurse           Sneha G S
# 4    5.0  Nursing Assistants    Nurse           Sneha G S
#
#   Question Type(if any)                                          Questions  \
# 0                   NaN         Why did you decide on a career as a nurse?
# 1                   NaN         What do you find rewarding about this job?
# 2                   NaN  How do you deal with someone who isn’t satisfi...
# 3                   NaN  Tell me what you feel your greatest skill as a...
# 4                   NaN           How do you handle the stress of the job?
#
#                                              Answers  \
# 0  I come from a long line of nurses. Both my gra...
# 1  I truly love helping people, and when those pe...
# 2  While I constantly strive to do everything I c...
# 3  I’m very proud of my ability to really listen ...
# 4  I find the best way to handle the stress of th...
#
#                                          Source link
# 0  https://theinterviewguys.com/nursing-interview...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   S.No.                  1049 non-null   float64
#  1   Topic                  1055 non-null   object
#  2   Job Role               1055 non-null   object
#  3   Collaborator's Name    1055 non-null   object
#  4   Question Type(if any)  68 non-null     object
#  5   Questions              1054 non-null   object
#  6   Answers                1051 non-null   object
#  7   Source link            74 non-null     object
# dtypes: float64(1), object(7)
# memory usage: 66.1+ KB

# %%
df.shape
# Out:
# (1055, 8)

# %%
df.isna().sum()
# Out:
# S.No.                      6
# Topic                      0
# Job Role                   0
# Collaborator's Name        0
# Question Type(if any)    987
# Questions                  1
# Answers                    4
# Source link              981
# dtype: int64

# %%
## Drop columns that are not needed
df = df.drop(columns = ['S.No.', "Collaborator's Name", "Question Type(if any)", "Source link"])

# %%
df.isna().sum()
# Out:
# Topic        0
# Job Role     0
# Questions    1
# Answers      4
# dtype: int64

# %%
## drop rows with null values
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Topic        0
# Job Role     0
# Questions    0
# Answers      0
# dtype: int64

# %%
df.shape
# Out:
# (1050, 4)

# %%
df.head(5)
# Out:
#                 Topic Job Role  \
# 0  Nursing Assistants    Nurse
# 1  Nursing Assistants    Nurse
# 2  Nursing Assistants    Nurse
# 3  Nursing Assistants    Nurse
# 4  Nursing Assistants    Nurse
#
#                                            Questions  \
# 0         Why did you decide on a career as a nurse?
# 1         What do you find rewarding about this job?
# 2  How do you deal with someone who isn’t satisfi...
# 3  Tell me what you feel your greatest skill as a...
# 4           How do you handle the stress of the job?
#
#                                              Answers
# 0  I come from a long line of nurses. Both my gra...
# 1  I truly love helping people, and when those pe...
# 2  While I constantly strive to do everything I c...
# 3  I’m very proud of my ability to really listen ...
# 4  I find the best way to handle the stress of th...

# %% [markdown]
# ### Text cleaning and preprocessing

# %%
## preprocessing of the dataset, removeing punctuations and make lowercase

def preprocess_text_column(df, column_name):
    # stemmer = PorterStemmer()
    # stop_words = set(stopwords.words("english"))

    # Function to preprocess a single text
    def preprocess_text(text):
        # Remove punctuation and convert to lowercase
        text = text.translate(str.maketrans("", "", string.punctuation)).lower()
        # Tokenize the text
        words = word_tokenize(text)
        # Remove stopwords and apply stemming
        # words = [stemmer.stem(word) for word in words if word not in stop_words]
        # words = [word for word in words if word not in stop_words]

        # Join the processed words back into a single string
        return " ".join(words)
    # Apply the preprocessing function to the specified column
    df[column_name] = df[column_name].apply(preprocess_text)

    return df

# %%
cleaned_df = preprocess_text_column(df, 'Questions')

# %%
cleaned_df.head()
# Out:
#                 Topic Job Role  \
# 0  Nursing Assistants    Nurse
# 1  Nursing Assistants    Nurse
# 2  Nursing Assistants    Nurse
# 3  Nursing Assistants    Nurse
# 4  Nursing Assistants    Nurse
#
#                                            Questions  \
# 0          why did you decide on a career as a nurse
# 1          what do you find rewarding about this job
# 2  how do you deal with someone who isn ’ t satis...
# 3  tell me what you feel your greatest skill as a...
# 4            how do you handle the stress of the job
#
#                                              Answers
# 0  I come from a long line of nurses. Both my gra...
# 1  I truly love helping people, and when those pe...
# 2  While I constantly strive to do everything I c...
# 3  I’m very proud of my ability to really listen ...
# 4  I find the best way to handle the stress of th...

# %%
cleaned_df.Questions.unique()
# Out:
# array(['why did you decide on a career as a nurse',
#        'what do you find rewarding about this job',
#        'how do you deal with someone who isn ’ t satisfied with your patient care',
#        'tell me what you feel your greatest skill as a nurse is',
#        'how do you handle the stress of the job',
#        'are you comfortable working with other doctors and nurses',
#        'what do you find is the hardest part about being a nurse',
#        'why are you the best nursing candidate for this position',
#        'tell me about yourself',
#        'why are you leaving your current position',
#        'why do you want to work here',
#        'would you say you ’ re a team player',
#        'describe a time you had to deal with a difficult patient and how you handled that',
#        'why should we hire you',
#        'if you disagree with a physician ’ s approach to treating a patient how do you handle it',
#        'how do you explain complex medical terms and procedures to patients who don ’ t have a healthcare background',
#        'how do you ensure you remain up to date on advances in nursing',
#        'when you don ’ t have an answer to a patient ’ s question what do you do',
#        'describe a time when you were in conflict with a fellow nurse how did you handle the situation',
#        'what are your responsibilities as a home health aide',
#        'how would you describe your primary duty as a medical assistant',
#        'how would you handle a situation where a patient refuses to take their prescribed medication',
#        'can you describe how you would resolve a conflict with a fellow nurse or healthcare professional',
#        'how would you manage a situation where a patients family disagrees with a prescribed care plan',
#        'what approach would you take to effectively communicate with a patient who doesnt speak english',
#        'if you made a mistake with a patients medication what actions would you take',
#        'what would you do if a patient complains about their pain not being managed effectively',
#        'how would you deal with a patient who is noncompliant with lifestyle recommendations',
#        'what would you do if a patients vital signs suddenly dropped',
#        'how would you handle a situation where you witness a colleague making a mistake',
#        'what would you do if you disagreed with a doctors treatment plan for a patient',
#        'can you share an instance when you went above and beyond in caring for someone',
#        'describe a situation where you had to make a quick decision that had significant implications',
#        'can you recall a particularly stressful situation in your past experiences and how you managed it',
#        'share an instance where you took a leadership role',
#        'can you provide an example of how you dealt with a particularly challenging individual',
#        'can you recall a time when you had to manage a medical emergency',
#        'can you share an instance where your communication skills made a significant difference to a situation',
#        'could you describe your method when confronted with a situation where a patient or their family disagreed with a doctors directives',
#        'can you provide an instance where you had to stand up for a patient',
#        'how have you dealt with a situation where you felt emotionally overwhelmed',
#        'how would you describe your character traits that make you suitable for a career in nursing',
#        'could you share an instance where your integrity was challenged and how did you respond to it',
#        'how have your life experiences shaped your personality in terms of handling stressful situations',
#        'can you tell us about a particularly challenging academic experience and how you managed it',
#        'how have your academic achievements prepared you for the nursing profession',
#        'what steps have you taken to ensure you can handle the academic rigor of nursing school',
#        'can you describe a challenging situation at work that tested your problemsolving skills',
#        'in what ways has your prior work history equipped you to tackle nursing schools demands and a future nursing profession',
#        'can you recall an episode at work where you manifested leadership qualities',
#        'how have your past work experiences prepared you for the challenges of nursing school and a career in nursing',
#        'can you discuss an instance where you demonstrated leadership at work',
#        'what influenced your decision to pursue nursing as a profession',
#        'how do you envision your contributions to the nursing profession',
#        'could you articulate the traits you deem most critical in a nurse',
#        'can you describe a situation where you had to make a decision under pressure what was the outcome',
#        'how would you handle a situation where you disagreed with a doctors orders',
#        'can you share an example of a complex problem you solved in a past experience',
#        'can you discuss an instance where you worked with someone from a different cultural background',
#        'how have you advocated for diversity and inclusion in your past experiences',
#        'what steps do you take to ensure you provide culturally competent care',
#        'what do you do if your replacement doesnt arrive on time',
#        'how would you handle a difficult patient',
#        'how would you handle a crisis such as an outbreak',
#        'how would you handle a patient who struggles with pain management',
#        'how do you respond when people ask for your personal diagnosis outside of a clinical setting',
#        'how do you handle workplace stress',
#        'why did you want to be a nurse',
#        'what do you find most rewarding about being a nurse',
#        'what ’ s the hardest thing about being a nurse',
#        'how do you explain medical concepts to patients and their family members',
#        'how would you treat a patient with symptoms of seasonal allergies',
#        'what techniques would you use to calm an upset patient',
#        'why do you want to work in health care',
#        'do you have strong computer skills',
#        'how do you ensure you follow guidelines for patient privacy',
#        'what type of office administration experience do you have',
#        'what kind of care does an elderly client need',
#        'have you already been faced with a patient who did not disclose important information how did you manage the situation and what was the outcome',
#        'tell me about your experience with a patient who required a lot of your time how did you care for this patient and still provide other patients with adequate care',
#        'how do you handle upset patients who present you with a complaint',
#        'do you know how to do electrocardiograms ekgs',
#        'do you have experience with medical coding and billing',
#        'how do you ensure that your patients receive the best possible care',
#        'what are your thoughts on the current state of home health care',
#        'what is your experience with caring for elderly or disabled patients',
#        'what are your thoughts on endoflife care',
#        'how do you deal with difficult family dynamics',
#        'what are your thoughts on providing personal care to patients',
#        'what are your thoughts on medication management',
#        'what are your thoughts on wound care',
#        'what are your thoughts on nutrition and diet for home health patients',
#        'what are your thoughts on exercise and physical activity for home health patients',
#        'what are your thoughts on socialization and activities for home health patients',
#        'what do you like most about being a nurse',
#        'what do you find most difficult about being a nurse',
#        'what are your strengths and weaknesses as a nurse',
#        'why did you choose nursing as your chosen profession',
#        'what do you think are the most important qualities of a successful nurse',
#        'what do you think are the biggest challenges facing nurses today',
#        'tell me about a time you dealt with an unhappy or difficult patient or family member',
#        'how do you explain medications treatments or healthcare situations without using a lot of medical or healthcare jargon',
#        'describe a time a patient was really happy with your care or a time you went above and beyond for a patient',
#        'describe a situation when you had to work with a difficult coworker what was the problem and how did you resolve it',
#        'describe a situation where you displayed teamwork',
#        'are you comfortable communicating with other members of the healthcare team describe a time there was a conflict with another member of a patient ’ s healthcare team',
#        'what do you do when you don ’ t know an answer to a patient ’ s question or how to address a situation',
#        'how do you handle changes to your assignment the unit schedule etc',
#        'describe a time you were under a lot of pressure how did you handle it',
#        'how well do you work with other nurses doctors and staff',
#        'how do you handle a situation where your replacement does not arrive on time',
#        'how would you handle a disagreement with a doctor',
#        'describe how you manage a busy workload',
#        'do you have any professional affiliations',
#        'how do you respond when people ask for your personal diagnosis outside a clinical setting',
#        'describe a situation when you had to work closely with a difficult coworker how did you handle the situation were you able to build a relationship with this person',
#        'talk about a conflict within your healthcare team what was the conflict and how did you handle it',
#        'describe a time when you were particularly proud of your healthcare team what was your role in this situation',
#        'tell me about a time you stepped into a leadership role',
#        'tell me about a time when a patient ’ s family was dissatisfied with your care how did you handle that situation',
#        'what approach do you take in communicating with people who do not know medical jargon give an example of a time you explained medical terminology to someone who is not medically trained',
#        'describe a time you provided effective patient or family education',
#        'talk about a time a patient or their family was particularly pleased and appreciative of your care',
#        'give an example of a time you had to interact with a hostile patient how did you handle the situation and what was the outcome',
#        'describe a time you were faced with a patient who chose not to communicate or disclose important information how did you handle the situation and what was the outcome',
#        'tell me about a time you were under a lot of pressure what was going on and how did you get through it',
#        'describe a time when your facility was undergoing some change how did that impact you and how did you adapt',
#        'tell me about a time when you didn ’ t know the answer to something at work how did you go about finding the information',
#        'give me an example of an awkward situation at work how did you remove yourself from the situation',
#        'tell me about a time you failed how did you deal with this situation',
#        'describe a time when you anticipated potential problems with a patient and initiated preventative measures',
#        'talk about a time you worked in a fastpaced setting how do you prioritize tasks while maintaining excellent patient care',
#        'describe your experience with a very ill patient who required a lot of your time how did you manage this patient ’ s care while ensuring your other patients were adequately cared for',
#        'talk about a time when you felt overwhelmed with your work or patientload what did you do',
#        'give an example of an important goal you set for yourself did you accomplish that goal how did you ensure that you accomplished it',
#        'give an example of a time when you were able to successfully persuade a patient to agree to something how did you persuade this person',
#        'describe a time when you were the resident medical expert what did you do to make sure everyone was able to understand you',
#        'tell me about a time when you had to rely on written communication to explain yourself to your team or to a patient',
#        'talk about a time when you had not communicated well how did you correct the situation',
#        'describe a time when you received negative feedback and turned it into something positive',
#        'what is one professional accomplishment that you are most proud of and why',
#        'talk about a challenging situation or problem where you took the lead to correct it instead of waiting for someone else to do it',
#        'have you ever felt dissatisfied with your work as a nurse what could have been done to make it better',
#        'describe a time when you went over and above your job requirements what motivated you to put forth the extra effort',
#        'give an example of a mistake you ’ ve made how did you handle it',
#        'what do you find most difficult about being a nurse how do you overcome this difficulty',
#        'when was a time you were overwhelmed and how did you overcome it',
#        'tell me about a time you were the sole educator in a given situation how did you ensure everyone understood',
#        'when was a time you were able to be creative in the workplace what was challenging and what did you enjoy about this experience',
#        'when was a time when you didn ’ t meet a patient ’ s expectations what happened and how did you resolve the situation',
#        'when was a time that you felt that you had failed what was your interpretation of the situation and what happened after',
#        'describe a time when your initial plan was altered what were the results',
#        'tell me about a time when you were required to use a form of written communication to express your ideas how did you do so effectively',
#        'when was the last time you received constructive criticism how did you respond',
#        'how do you prioritize your patient ’ s needs when you are given a full assignment and have numerous tasks to complete',
#        'how do you ensure you meet the goals you set for yourself',
#        'why do you want to work as a midwife',
#        'what are the primary duties of a midwife',
#        'can you describe your experience with highrisk birth situations',
#        'how do you cope with pressure from work',
#        'how do you support pregnant parents during labour',
#        'what are your roles after a child is born',
#        'whats your opinion about maintaining a healthy diet during pregnancy',
#        'can you mention some safeguarding duties you perform during a stillborn birth',
#        'how would you approach a pregnant woman suffering from mental health issues',
#        'how do you handle working under pressure in a stressful environment',
#        'how do you react when you receive criticism',
#        'what are the most important qualities for a nurse midwife to have',
#        'how would you describe the relationship between a nurse midwife and a patient',
#        'what is the most important thing that a nurse midwife can do to help a patient feel comfortable and safe',
#        'if a patient came to you with a concern about a new symptom how would you help them understand the diagnosis',
#        'what would you do if you noticed a nurse or doctor making a patient feel uncomfortable',
#        'how well do you perform under pressure',
#        'when performing prenatal exams how do you make a patient feel comfortable and relaxed',
#        'we want to improve our communication with patients how would you implement a strategy to improve communication and educate patients about their care',
#        'describe your process for documenting a patient ’ s care and updating a patient ’ s medical records',
#        'what makes you stand out from other nurse midwives',
#        'which types of birth control do you recommend and why',
#        'what do you think is the most important thing for a patient to know about their care',
#        'how often do you update your knowledge about new developments in your field',
#        'there is a new treatment for a disease that affects many of your patients how do you help them understand the diagnosis and treatment plan',
#        'what do you think is the most important part of providing personalized care to a patient',
#        'describe your experience in providing postpartum care',
#        'how do you handle difficult conversations with patients such as discussing sensitive topics or breaking bad news',
#        'what strategies do you use to keep uptodate on medical advancements and research',
#        'what would you do if a patient has an unexpected reaction to treatment',
#        'describe the protocols you follow for monitoring fetal heart rate and other vital signs during labor',
#        'describe how you collaborate with other healthcare providers while treating a patient',
#        'how would you handle a hostile situation with a resident or a coworker',
#        'ok to work with covid19 patients',
#        'they asked me what i knew about the facility',
#        'why did you decide to apply to our hospital or medical center',
#        'how do you get along with others',
#        'what would you do if a coworker asked you to do something that is not in your job description',
#        'where do you see yourself in 5 years',
#        'are you computer literate',
#        'tell about a time youve advocated for a resident',
#        'what are the vital signs', 'where do you see myself in 5 years',
#        'how long as a certified nurse aide',
#        'basically why should we hire you',
#        'what is the duty of a certified nursing assistant',
#        'if someone was a dnr and they stop breathing how would you react',
#        'describe a time you went above and beyond for a patient or customer describe a time you needed help with your duties how did you approach the situation describe a time you had to deal with a problem at work how did you handle it',
#        'what would make you a good candidate for the job',
#        'are you okay with this type of work',
#        'how attached are you to your fake nails',
#        'describe your past experiences',
#        'have you had a a dnr patient before',
#        'what would you do if you saw a patient trying to get out of bed',
#        'what unit do you prefer to work on',
#        'where do you see yourself in 2 years',
#        'how i felt about diversity',
#        'i can see that you applied to many positions why are you interested in this one',
#        'describe a time that you showed good customer service',
#        'what would you do if you had a difficult patient',
#        'career goals plans for the future clinical interests',
#        'how would i calm down an agitated patient',
#        'what is a con about you',
#        'why do you want to work in long term care',
#        'why do you wan na work at parkway',
#        'what shift do you work any previous job experience',
#        'do you consider yourself a princess',
#        'can you work over time because no one every stays',
#        'why do i want to work here', 'are you reliable',
#        'what is something that you have yet to learn within your role as a cna',
#        'tell me something about yourself',
#        'are you willing to get sometimes over working hours on your duty',
#        'tell us a little about yourself',
#        'question pertaining to a difficult situation in my former role',
#        'why do you want to work for us', 'why did i become a cna',
#        'what is one thing you need to work on',
#        'how would you deal with a patient who is in risk of elopment',
#        'when can you start', 'how i found this job',
#        'what are my strength and weaknesses',
#        'how to you interact with your coworkers in stressful situations',
#        'how many years experience i have',
#        'how did you overcome an obstacle you were faced with in the past please provide an example',
#        'what is the most important thing to take into consideration when working in a hospital',
#        'what is your experience like',
#        'do you have any reason that would prevent you from working your scheduled shifts transportation do you feel like you will enjoy working in a nursing home enviroment',
#        'a common one i find at most interviews which happened at this interview is tell me about yourself',
#        'experience level are you ok with frequent mandating',
#        'what is one of your weaknesses',
#        'would you be available to come in on short notice',
#        'why should they hire me i already had a cna license in missouri but they liked that i was certified in kansas as well',
#        'what hours are you available',
#        'what are your goals where do you see yourself in 5 years in the nursing profession',
#        'what is one experience you had with a difficult familypatient and how did you handle it',
#        'what values could you bring to pmc',
#        'what i expect out of my work environment',
#        'describe diversity in one word without using the word different',
#        'tell me a little bit about yourself where have you worked what are your expectations',
#        'how youve served the community',
#        'transferring patients with a hoyer and how to deal with different cnas and their attitudes and basically do you know your job',
#        'they asked me to describe the situation when i saw a patient of mine declining in some way and what did i do and what was the outcome',
#        'describe a situation where you feel you could have provided safer patient care',
#        'what do you like about crotched mountain why are you applying here',
#        'experience is necessary but i am so grateful they gave me a chance even though i was a newly certified nursing assistant and thanked them so much',
#        'i was asked about my experience and what i want out of a position',
#        'would i be able to do a drug screen that day',
#        'are you certified nursehad cpr how many years experience do you have skill in alzheimer unit',
#        'to do the very best you couldgood place to work if you like 12 hrs work days',
#        'how do i handle a conflict with my coworker',
#        'they were in a major staffing crisis so unexpected was only after approximately 5 minutes when can you start',
#        'proper way to bathe a resident',
#        'what experience do have relative to this job',
#        'when could i start working',
#        'how did you deal with a difficult coworker',
#        'how would you approrach having an argument with a nurse',
#        'what hours am i available',
#        'they asked about my experience in working on a team',
#        'how soon are you available for work',
#        'why are you a good fit for this position',
#        'why did i want to work for their company',
#        'what would you do is someone called out and you had to take on more patients',
#        'why orlando health do you prefer days or nights talk a little about your past experience',
#        'why do you want to be a cna',
#        'behavior questions schedule tasks vital signs',
#        'what do you see yourself doing five years from now',
#        'how long have you been a cna what is a logical reason for calling into work',
#        'what your qualifications as a cna',
#        'what makes you a good candidate',
#        'if i had worked somewhere previously', 'who was your best boss',
#        'how do you handle stressful situations',
#        'what kind of job do you really want',
#        'what made me interested in nursing',
#        'why do u want to work there', 'how to operate the machinary',
#        'can i be called on a particular day',
#        'whatâ€™s your ideal work environment',
#        'what is your goal working here',
#        'what is your interest in nursing',
#        'what are some things you do for selfcare',
#        'how long have you work as a nursing assistant',
#        'what would you do if there was conflict with another coworker',
#        'how do you organize yourself when you have multiple test to complete',
#        'how many years have i done this kind of work',
#        'job related experience and how to handle it',
#        'how did you resolve a client conflict',
#        'how long have you worked as a cna',
#        'what do you think is the most important aspect of company culture',
#        'why do you want to work at sutter health',
#        'tell us about your experience', 'tell me about your job',
#        'whats the most hrs a week u would work',
#        'how do you deal with a difficult patient',
#        'how long was you a cna', 'tell me a bit about yourself',
#        'what do you want to do in the future as a nurse',
#        'what had been your most difficult assignment and how did i handle it',
#        'why are you interested in patient care',
#        'how are you doing today',
#        'what qualities do you bring to a team what differentiates good care and excellent care or something like that i cant remember the rest but they were pretty basicstandard questions',
#        'do you enjoy working with the elderlydo you know how to use a manual blood pressure cuff do you know how to use a holey left have you ever worked in a nursing home setting do you know how to give a male and a female resident a bath do you know how to feed the resident do you know how to read their menu slip to make sure the right food is on their tray do you know how to properly make up a bed how to transfer a resident from a wheelchair to the bed or from a bed to a wheelchair do you come to work on time or you a dependable person do you call out often',
#        'what experience do you have',
#        'why do you want to work for the va',
#        'how do you feel about working with terminal patients',
#        'what made you become a cna',
#        'what sets me aside from other applicants',
#        'what is the biggest mistake you have made',
#        'where i got my certification if i had experience with the elderly',
#        'why did i become a nursing assistant',
#        'i was asked for my resume while working her through another registry',
#        'my last salary', 'how many hours are you looking for',
#        'that i make sure you assist a lift with 2 people',
#        'i do not remember a difficult question',
#        'why did i want to work for them',
#        'what doi like most about my job',
#        'how many years i have been in the field they ask that before you even get a interview',
#        'what are some of your strengths',
#        'what hours would you be interested in',
#        'interviewed with two people', 'job experience',
#        'asked at least 3 times if i had any questions',
#        'why do you want to be cna here',
#        'they asked about a scenario in which the patient needed tending to they asked what would be priority in the scenario',
#        'how do you feel about being in a situation where you have to do something youve never done before',
#        'why are u applying for this position',
#        'give an example of a negative situation that you were able to turn around into a positive one',
#        'they asked me when i could start', 'why i applied there',
#        'why elder care', 'how did you hear about our company',
#        'when can you start what shift are you able to work',
#        'what is your availability l',
#        'not to diagnose a patient but to see holistic care i mean how to react to certain situations',
#        'tell me about a time you went over and beyond with your customer service',
#        'what would i do if a nurse asked me to feed a patient applesauce that had their meds in it',
#        'pretty much the same qualifications experiences and availability',
#        'what role do you play when working with a team',
#        'why did you choose this facility',
#        'about my experience and why i wanted to work there',
#        'how many years of experience do i have in healthcare',
#        'tell me a little about yourself',
#        'what makes you stand out from the other applicants',
#        'do you want to join our cna union',
#        'why did you decide to apply to bellin health',
#        'previous work experience with that type of floor and medical specialty',
#        'the asked about myself and very forward with how much they pay',
#        'how do you feel you can be an asset in this position within carter healthcare',
#        'how do you handle difficult patients',
#        'what do you do when you first enter a patient ’ s room',
#        'what is a cna responsible for', 'what are your strengths',
#        'what are your weaknesses',
#        'what would you do if a patient refuses care',
#        'what are your career goals',
#        'tell me about a time you and your coworker didn ’ t get along how did you handle it',
#        'tell me about a time when you had to do something difficult how did you handle that',
#        'as a cna what sets you apart from others',
#        'where do you see yourself in five years',
#        'what do you do when entering a patient ’ s room',
#        'do you have any questions about the position or company',
#        'what is your greatest achievement as a medical professional',
#        'why do you want to work at our health facility',
#        'how would you handle a disagreement with a nurse or doctor',
#        'how would you deal with an aggressive patient',
#        'what do you think will be the biggest challenge in this role',
#        'questions to ask an employer at a cna interview',
#        'are there any duties you are not willing to perform',
#        'are you thinking about pursuing education to become an lpn or rn',
#        'tell us about a time when you had to do something difficult how did you handle that and how can that help you as a cna',
#        'as a cna what do you bring to the company that sets you apart from others',
#        'what motivated you to become a nursing assistant',
#        'can you describe your experience with taking vital signs and recording them accurately',
#        'describe your experience in assisting patients with activities of daily living adls',
#        'have you ever had to deal with a patient experiencing a medical emergency if so how did you handle it',
#        'what is the proper procedure for transferring a patient from their bed to a wheelchair',
#        'explain the importance of infection control measures in a healthcare setting',
#        'how do you maintain patient confidentiality while working as a nursing assistant',
#        'describe your experience with wound care and dressing changes',
#        'what steps do you take to ensure accurate documentation of patient information',
#        'can you explain the role of a nursing assistant in a patient ’ s plan of care',
#        'how do you manage your time effectively when caring for multiple patients',
#        'describe your experience with administering medications under the supervision of a nurse',
#        'how do you communicate with patients who have difficulty understanding or speaking english',
#        'what strategies do you use to build rapport with patients and their families',
#        'how do you stay uptodate on best practices and new developments in the field of nursing assistance',
#        'describe a challenging situation you faced as a nursing assistant and how you resolved it',
#        'can you discuss your experience with endoflife care and providing emotional support to patients and their families',
#        'how do you assist patients with mobility issues such as walking or repositioning in bed',
#        'how do you handle situations where a patient is experiencing pain or discomfort',
#        'what is your approach to maintaining a clean and organized work environment',
#        'can you discuss any specialized training or certifications you have such as cpr or first aid',
#        'how do you handle the emotional stress that can come with working as a nursing assistant',
#        'describe your experience in assisting patients with personal hygiene tasks such as bathing and grooming',
#        'have you ever encountered a situation where you suspected patient abuse or neglect if so how did you handle it',
#        'how do you ensure effective communication with other members of the healthcare team such as nurses and physicians',
#        'why do you believe you would be an excellent fit for our facility as a nursing assistant',
#        'are you certified as a nurse assistant',
#        'what are your qualifications as a nurse assistant',
#        'how would you describe your personality',
#        'provide an example of when you utilized your communication skills as a nurse assistant to resolve an issue',
#        'if a patient was hostile toward you how would you handle the situation',
#        'what would you do if you noticed another nurse assistant was struggling with a patient',
#        'we want to improve our patient ’ s experience what would you do to make our patients feel more comfortable',
#        'which nursing techniques do you prefer to use when caring for patients',
#        'what do you think is the most important aspect of being a nurse assistant',
#        'there is a high volume of patients and your shift leader is unavailable what would you do to stay focused and complete your duties',
#        'what challenges have you faced as a nurse assistant and how did you overcome them',
#        'are you comfortable assisting patients with mobility issues',
#        'what would you do if you noticed a discrepancy between the charted information and the actual patient ’ s condition',
#        'how do you stay up to date on medical advancements and procedures',
#        'tell us about a time that you were in a leadership position were you pleased with the results',
#        'describe a situation where you felt proud of your healthcare team what role did you play in your team ’ s success',
#        'how do you like working with a team',
#        'describe a time there was a miscommunication between you and a teammate how did you handle it',
#        'describe a problematic patient you have had in the past how did you handle the situation',
#        'how do you address questions from a patient ’ s family and friends',
#        'can you explain situations without using a lot of medical jargon give an example',
#        'what is your idea of effective patient and family education',
#        'have you dealt with a family or patient who was displeased with your care how did you handle it',
#        'why did you decide to be a nurse',
#        'what are your strengths and weaknesses',
#        'how do you deal with cultural differences',
#        'what are your professional goals',
#        'what do you do when you don ’ t know the answer to something at work—whether it ’ s how to address a situation or answer a patient question—how do you go about getting more information',
#        'what ’ s your strongest skill as a nurse',
#        'what would you do if you felt a patient was being abused',
#        'what is was looking for in a job', 'normal basic questions',
#        'how long have i worked in the field',
#        'just asked about your background in the position',
#        'can you draw blood no other questions regarding my training physicians id worked with nor about my 25 years of medical assisting skills etc',
#        'why o wanted to work for them',
#        'what are some of your strong points in the work place',
#        'how good are you at multitasking',
#        'have you ever worked from home or online before',
#        'describe your experience',
#        'why did you decide to choose to apply to wellstar',
#        'what is one of your weakness at work',
#        'if i can handle bloody situations and open wounds',
#        'are you willing to do things beyond your job description to help the familybusiness',
#        'what would be your biggest challenge what do you do with a conflict between a coworker how do you respond to high stress environment what is a weakness of yours what is a strength how would you deal with a coworker acting in an unsafe manner with a patient',
#        'where are ekg leads placed not the exact question but pretty close',
#        'are you available to work 12hr shifts and possible overtime',
#        'what attracted you to this job',
#        'can you tell me one of your weaknesses',
#        'do you have any prior experience',
#        'how long have you been a medical assistant',
#        'what is your background as a medical assistant and skills with pediatrics',
#        'what made me consider this company',
#        'tell me about a time when you had to deal with a coworker that was hostile',
#        'how do you handle drama in the work place',
#        'do i consider myself more of an extrovertintrovert',
#        'how many times were you late for work in the past year',
#        'tell me a time when you had a argument with a boss',
#        'what made you leave your previous job',
#        'something positive and negative about myself',
#        'what do you know about this company',
#        'what is your long time career goal',
#        'how would your friends describe you',
#        'tell us of a time from work where you know you were right but your supervisor asked you to do something different',
#        'given a set of images that represent cross sectional slices of a 3d series representing the heart how would you calculate the internal volume',
#        'describe yourself', 'availability to work',
#        'what is the goal or goals you have when treating patients',
#        'what is your best quality for this job',
#        'where do you see yourself in 5 years why should we hire you',
#        'aptitude testing',
#        'a time you went beyond and above for a patient',
#        'he just started talking about himself',
#        'how did you handle conflict at your last place of employment',
#        'do you speak any other languages',
#        'do you have your certification', 'why do you want to teach',
#        'why i was choosing dermatology and cosmetic surgery',
#        'what did you do when dealing with a difficult coworker',
#        'do you have children',
#        'was i able to work with more then 2 doctor s at a time',
#        'how many patients would you consider a lot',
#        'how do you feel about old people',
#        'what did you like about school the most',
#        'they asked about my experience',
#        'why would you be the best candidate to work here',
#        'tell them alittle about yourself',
#        'i was asked by two members of the management team how old i was i did not expect to be asked about my age and felt the questioning should have been directed toward my experience and education the management team could have easily assessed my age by the background check or made a best guess by my resume',
#        'regular questions', 'how far away from the office to you stay',
#        'are you still working temporarily do you want a full time permanent position here',
#        'are any of my family members sick',
#        'what do you do in your spare time at work',
#        'why should they hire me', 'how long i worked in healthcare',
#        'are you a certified medical assistant',
#        'why i was looking to leave my current employer',
#        'how do you interact in a team environment',
#        'how would i deal with a situation that has occurred differently',
#        'when you wake up in the morning and look at yourself in the mirror what do you see',
#        'do you think its fair to treat every patient the same',
#        'why would you like to work at scripps', 'what is your weakness',
#        'why you want to work for piedmont', 'how many days are u open',
#        'how many years of experience in medical field',
#        'what made you choose medstar',
#        'would you like to further your education',
#        'what would you do if you had a problem student in your class',
#        'do you speak spanish', 'do you have a phlebotomy certificate',
#        'why i felt i was a good candidate for the job',
#        'do u have a drivers license and reliable transportation',
#        'how much did they think i would be comfortable accepting as a wage hourly',
#        'what type of clinical experience do you have',
#        'do you work well with others',
#        'if your last supervisor would say something negative about you what would it be',
#        'why did you leave your last job',
#        'what do you know about the role', 'why yager esthetics',
#        'will you be able to control what you say to a patient do you know how to speak to a patient',
#        'tell us about yourself do you have any children',
#        'i was asked if i work well as a team player or do i work better alone',
#        'can you work 50 hours plus a week',
#        'they asked about my skill set past employment and job description',
#        'what qualities and skills did i have why do j want to work here what could i bring to the company',
#        'could i get my certification by a certain time',
#        'how would you handle an angry patient',
#        'how would you deal with a difficult patient in regards to insurance',
#        'what is it about agora that lured you to apply for this position',
#        'how do you like working in the medical field',
#        'are you bls certified',
#        'how far away is the facility from your house are you ok with that',
#        'they asked about my experience with a certain software',
#        'what about the medical field interest you',
#        'my experience in health care',
#        'i found the questions irrelevant nothing to do about practicing medicine but more about your availability to work anytime and all the time',
#        'what makes me feel that i could handle this position and responsibilities due to my limited experience in orthopaedics',
#        'are you willing to drive this far 1 hour each way per day',
#        'what would you do if you had an angry patient yelling at you',
#        'are you willing to relocate to different sites',
#        'why do you chose rhode island free clinic', 'experience',
#        'what would you say if i were to ask you what others think of you',
#        'how many hours can you work per week', 'past experiences',
#        'mainly about your personal experience',
#        'why should they hire me when i have been out of the field for a few years',
#        'expectation', 'they ask about the salary expectation',
#        'why do i want to teach medical assisting how many years experience do you have',
#        'why are you leaving your current employer',
#        'we have a nophone policy here at reddy medical group only providers may have a phone on them no exceptions what would you do if you saw a fellow employee on hisher phone during work hours',
#        'about family languages spoken what i can do etc',
#        'the question is basically about general story',
#        'can you numb a patient',
#        'tell us a time you had to respond to an unexpected change',
#        'basic questions in this interview customer service experience and what it means to you is a question',
#        'if i have experience teaching in another language besides english',
#        'what job duties did i perform during my last job',
#        'why do you think you would be a good fit for fhc',
#        'my years of experience',
#        'math for calculating prescription dosage', '5 rights',
#        'how would i handle confidentiality',
#        'where do i see myself in 5 years', 'was i willing to commute',
#        'ability to handle stress multitask and deal with difficult patients',
#        'why do you want to work here and why did you choose to become a medical assistant what personal skills do you have that make you a great ma',
#        'what can i bring to the company',
#        'if i know how to start an iv on a patient', 'are you bilingual',
#        'tell me about you',
#        'what is one thing about patient care that appeals to you',
#        'when are you avaiable to work',
#        'have you worked in dermatology before if so what were some of your duties',
#        'why are you leaving your current job',
#        'typical why did you leave your last job',
#        'why is training important and can you list any recent training that has been beneficial to you',
#        'why did you leave your last employer',
#        'can you work 247 shift pattern',
#        'to describe my skills and knowledge',
#        'if you could be any animal what would you be',
#        'the most difficult question was being asked if i speak spanish',
#        'why are you interested in medicine',
#        'management focused quite a bit on transportation availability and commute issues otherwise toughest question was along the lines of how i would treat a different cultured patient with specific laws garnered to them',
#        'a time when i went above beyond for a patient',
#        'how did you make a patient feel comfortable based on previous experiences',
#        'what im good at in the labï‚§ phlebotomy venipunctures and urinalysistaking vital signs ekgâ€™s and aseptic techniques specimen collection and medical office administration management cpt4 icd9 coding and clinical office proceduresproficient with various computer applicationâ€™s such as ms word excel powerpoint skillful in the clinical and administrative duties of a medical assistant excellent organizational and people skills type 35wpmcpr certified valid until 2017',
#        'introduce yourself what is your expected wage when can you work this is a casual position if your ok with it',
#        'there were none it would have been nice to have an interview',
#        'what is your favorite pizza',
#        'how would you deal with a rude patient',
#        'what can you tell me about the company',
#        'explain a conflict you had with a coworker and how you resolved it',
#        'what do you know about the company',
#        'when is the earliest can you start', 'personal',
#        'what experience do i have and what would i bring to the healthcare field',
#        'tell me about your education',
#        'basic questions how did you deal with a difficult manager',
#        'strengthsweaknesses why do you want to work here',
#        'do you have experience with hoyer lifts or quadriplegic care',
#        'how do you like working with elderly',
#        'they wanted to copy my social security card and drivers license before the interview',
#        'how do you handle a client being angry at you or taking their anger out on you',
#        'if i knew how to transfer patients', 'how do you handle stress',
#        'how many years of caregiving experience do you have',
#        'why do you want to work here do you enjoy working with seniors',
#        'they when can i start', 'have you ever worked for us before',
#        'describe a problem you ran in in your previous or current job what did you do to solve the problem and how did you feel at the end',
#        'since i was a preferred worker they wanted to know who i would be the caregiver for',
#        'how many years of experience', 'if i had done home health before',
#        'can you take a quick test on your knowledge as a home health aide or cna',
#        'do you feel comfortable working as an aid',
#        'have you worked directly with people before if so to what capacity',
#        'what is expected wage', 'was i willing to travel',
#        'what was my experience in the field',
#        'what qualifications do you have for this job',
#        'they ask a few questions about a time you had to deal with a irate customer',
#        'what caused my choice of work',
#        'what do you do if the client does not answer the phone or door',
#        'most difficult question was what i would do if there was a client who didnt like me being in a positive mood',
#        'how well i thought i could cook on a scale from 110',
#        'do have any experience in taking care of a person',
#        'where do you live', 'i was asked about experience in the field',
#        'tell me about yourself that is not on your cv',
#        'why do you want to work with us',
#        'hardest questions on the test are about hepatitis aband c',
#        'background', 'what are my strengths', 'why i chose their company',
#        'they asked why do i wan na join their company as well as what am i willing to learn from them and how do i feel that i can grow from the company as well',
#        'why did i like being a home care worker',
#        'how i feel about working in a home that have dogs or cat',
#        'do you have any experience in this line of work',
#        'how much experience do you have', 'why did i want this job',
#        'strength vs weaknes',
#        'am i a reliable worker the overall of my experience is to be dedicated and hard working',
#        'what makes you interested in this job',
#        'what kind of job are you interested in what would you have the most trouble with what would your reference say about you what are your strengths',
#        'howd i find out about the job', 'what i could bring to covenant',
#        'what do you like most about working with the elderly',
#        'asked medical terminology and expected you to know the answers even if you said you had no experience in the field',
#        'are you able to work 247 which i pretty much do',
#        'if you had to be to work on monday but a family emergency arises how would you handle it',
#        'what is my availability and times',
#        'previous experience it is very relaxed and casual they ask your availability note they will start you with the worse cases but hang in there as they have will give you more stable hours with one patient or a couple to relive in a regular basis in less than one month',
#        'what are some of your achievements',
#        'how do you deal with difficult clients',
#        'what was my current job',
#        'how long have you been working as a home health aide',
#        'i am interested in getting interviews',
#        'have you heard of our company',
#        'what is health and diseases what is role of society in keeping society health what role of health extension awaking society',
#        'asked if i was comfortable going into clients homes',
#        'i didnâ€™t have a difficult question they were all pretty normal interview questions',
#        'do you know not to touch blood and wear gloves can you watch nurse training videos on youtube',
#        'do you have any questions', 'when i could start',
#        'what interested me about this homecare place instead of others in the area',
#        'proof of first aide training',
#        'one thing that they asked me was to tell them something about myself how much experience did i have at being a home health aide where do i see myself in five years what is my strengths and weakness',
#        'how old are you',
#        'can i handle with personal care duties such a bathing dressing etc',
#        'what is your experience', 'what does an hha do',
#        'what skills contribute to your ability to be an aide',
#        'they asked why i wanted to work with the elderly and disabled',
#        'if i was certified',
#        'what type of experience do you have and with what type of patients are you cpr certified what type of patient are you comfortable working with why do you like being a home health aide',
#        'why do i want to be a home health aidecaregivercompanion',
#        'are you able to work full time', 'why did i want to work there',
#        'why do you want to work for maxim',
#        'i dont believe they asked me a difficult question',
#        'do you want the job', 'your availabilities',
#        'do you have any experience working with elderly or dementia clients',
#        'do you have any experience working with the elderly',
#        'how you every worked as a home health aide before what is your expected pay how do you feel about working someone on hospice',
#        'have you ever done wrong to any elderly',
#        'how do you handle being frustrated with a client',
#        'why do you wan na work for us',
#        'why do you think youd be a good fit for this job',
#        'why i would like to work in this profession',
#        'what would your former employer say about you if we called them right now',
#        'why i wanted to be a home health aide',
#        'how long was i doing this',
#        'why should she give me a chance to work for partner in care',
#        'how comfortable i was with different situations',
#        'you have to have with you on application process state id state certification liscand cpr cards are a must to have at the interview',
#        'what was your schedule like', 'what is one weakness',
#        'what do you see yourself doing in the next 5 years',
#        'do you have experience caring for individuals who may be affected by a disability',
#        'how can i get full time what is it i need to do to become apart of this company i dont feel like a part of the company being contigent',
#        'have you worked with elderly people before',
#        'have you had experience in the health industry',
#        'drivers licenae', 'do you have proff of car insurance',
#        'have you worked with disabled people and dementia bed bound autism',
#        'what are your work experience', 'did i have experience',
#        'what to do in a certain situation if clients act out',
#        'how many times have you been absent',
#        'if i knew how to work a hoyer life and gait belt',
#        'typical customer service questions',
#        'why did you apply for position',
#        'why should you be imployed here',
#        'why are you wanting to leave your current position no reason',
#        'why i wanted to work for them',
#        'why do you think you would fit well with our company',
#        'tell us why you want to be a home health aid',
#        'were did i last work', 'why do i like what i do',
#        'what my avalibility',
#        'drug screen background testing and employment verification',
#        'how was my recent interviews', 'schedule youre willing to work',
#        'do you have reliable transportation',
#        'why do you want to do this job',
#        'if you saw a coworker stealing from a client what would you do',
#        'what makes you want to care for the elderly',
#        'how would you feel if i told you to go feed and bathe a 300 pound man',
#        'drivera liaence', 'was i certified',
#        'are you familiar with ambulation hoyer lifts and calloscopy bags',
#        'how often paid and if any benefits', 'when are you available',
#        'experience certificates', 'do you have experience',
#        'how much do they pay and what are the benefits',
#        'typical questions were asked for the interview',
#        'whether i was on any public assistance or not why is it going to be held against me if im not',
#        'years of experience', 'have you ever cared for an older person',
#        'if hired and you saw a client had an icy drivewaysidewalk and you werent on duty would you take care of the issue paraphrase',
#        'experience for the positiion i have worked at an facility for over 15 years and worked with the public as well and im very comfortable with helping others in their time of distress',
#        'how was i referred', 'why would you want to work here',
#        'strength and weakness experiences how to handle certain situations',
#        'do i mine taking a drug test',
#        'how do we fix the balance between female and male employees',
#        'how did i find out about bayada',
#        'previous work history related to the job post',
#        'why did you want to become a home health aide',
#        'what makes you qualified for this',
#        'what made you choose to become a home health aide',
#        'what are the most important qualities for a successful home health aide',
#        'what are the challenges you face in your job',
#        'how do you think the role of the home health aide will change in the future',
#        'what are the most important things you hope to accomplish in your career',
#        'how do you deal with difficult emotions such as sadness or anger',
#        'do you have any questions for us',
#        'give me a short brief about yourself',
#        'what do you find most pleasing about being a nurse',
#        'what do you think of your earlier boss',
#        'what do you think is the hardest thing about being a nurse',
#        'how would you handle a crisis',
#        'how do you hold working with other nurses staff and doctors',
#        'how do you react in stressful situations',
#        'name some skills that are mandatory for a nurse in order to be successful in hisher career',
#        'would you become a doctor',
#        'what sort of salary are you looking for',
#        'where do you see yourself in the next upcoming years professionally',
#        'tell me about your extraordinary certifications and training',
#        'how do you use organizational skills in your daily responsibilities as a nurse',
#        'which factors give out as a motivation for you in this job',
#        'why do you want to be a medical assistant',
#        'tell me about your previous experience as a medical assistant',
#        'what do you think makes a good medical assistant',
#        'describe a time when you solved a problem involving a patient',
#        'what experience do you have with medical technology',
#        'how familiar are you with hipaa protocol and how will you protect patients ’ confidentiality'],
#       dtype=object)

# %%
## reset the index to indexing errors
cleaned_df.reset_index(inplace = True, drop = True)

# %% [markdown]
# ### Grouping questions according to similarity scores using a 0.5 similarity score threshhold

# %%
## this code does not capture every question due to some comaparisons fail to cross the threshhold
# cleaned_df is a pandas dataframe containing questions and answers

# Extract TF-IDF features from the questions
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_df['Questions'])

# Calculate the pairwise cosine similarity between questions
cosine_similarities = cosine_similarity(tfidf_matrix)

# Define a threshold for grouping questions
threshold = 0.5

# Create an empty list to store the groups
grouped_questions = []

# Create a dictionary to store question-to-group mapping
question_to_group = {}

# Counter for group numbering
group_number = 1

# Iterate through the cosine similarity matrix
for i in range(len(cleaned_df)):
    # Check if the question is already assigned to a group
    if i not in question_to_group:
        # Initialize an empty list to store the current group
        current_group = [i]

        # Iterate through the cosine similarity scores for the current question
        for j in range(len(cleaned_df)):
            if i != j and cosine_similarities[i, j] >= threshold:
                current_group.append(j)
                # Mark the question as assigned to the current group
                question_to_group[j] = group_number

        # If the current group contains more than one question, add it to the list of groups
        if len(current_group) > 1:
            grouped_questions.append(current_group)
            # Increment the group number
            group_number += 1

# Print the grouped questions with group numbers
for group_number, group in enumerate(grouped_questions, start=1):
    print(f"Group {group_number}:")
    for i in group:
        print(cleaned_df.loc[i, 'Questions'])
# Out:
# Group 1:
# why did you decide on a career as a nurse
# why did you decide to be a nurse
# why did you decide on a career as a nurse
# Group 2:
# what do you find rewarding about this job
# what do you find most rewarding about being a nurse
# what do you find most rewarding about being a nurse
# what do you find rewarding about this job
# Group 3:
# how do you deal with someone who isn ’ t satisfied with your patient care
# how do you deal with someone who isn ’ t satisfied with your patient care
# Group 4:
# tell me what you feel your greatest skill as a nurse is
# what ’ s your strongest skill as a nurse
# tell me what you feel your greatest skill as a nurse is
# what ’ s your strongest skill as a nurse
# Group 5:
# how do you handle the stress of the job
# how do you handle workplace stress
# how do you handle workplace stress
# how do you handle stress
# how do you handle stress
# do you want the job
# how do you handle the stress of the job
# Group 6:
# are you comfortable working with other doctors and nurses
# how well do you work with other nurses doctors and staff
# are you comfortable working with other doctors and nurses
# how do you hold working with other nurses staff and doctors
# Group 7:
# what do you find is the hardest part about being a nurse
# what do you find most rewarding about being a nurse
# what ’ s the hardest thing about being a nurse
# what do you find most difficult about being a nurse
# what do you find most difficult about being a nurse
# what do you find most rewarding about being a nurse
# what do you find is the hardest part about being a nurse
# what do you find most pleasing about being a nurse
# what do you think is the hardest thing about being a nurse
# Group 8:
# why are you the best nursing candidate for this position
# why are u applying for this position
# why would you be the best candidate to work here
# why would you be the best candidate to work here
# why are you the best nursing candidate for this position
# Group 9:
# tell me about yourself
# tell me about yourself
# tell me something about yourself
# tell us a little about yourself
# tell me about your job
# tell me a bit about yourself
# tell me about yourself
# tell me about yourself
# tell me about yourself
# tell me a little about yourself
# tell me about yourself
# tell me about yourself
# tell me about yourself
# tell me about yourself
# tell me about yourself
# tell me about yourself
# tell them alittle about yourself
# tell them alittle about yourself
# tell me about yourself
# tell me about you
# tell me about yourself
# what can you tell me about the company
# tell me about your education
# tell me about yourself that is not on your cv
# tell me about yourself
# tell me about yourself
# Group 10:
# why are you leaving your current position
# why are you leaving your current position
# why are you leaving your current position
# why are you leaving your current employer
# why are you leaving your current position
# why are you leaving your current position
# why are you leaving your current job
# why are you leaving your current position
# Group 11:
# why do you want to work here
# why do you want to work in health care
# why do you want to work here
# why do you want to work here
# why do you want to work as a midwife
# why do you want to work here
# why do you want to work here
# why do i want to work here
# why do you want to work for us
# why do you want to work here
# why do you want to work here
# why do you want to work here
# why do u want to work there
# why do you want to work for the va
# why did i want to work for them
# why do you want to work for us
# why do you want to be cna here
# why do you want to work here
# why do you want to work here
# why do you want to work here
# why do i want to work here
# why you want to work for piedmont
# why you want to work for piedmont
# what qualities and skills did i have why do j want to work here what could i bring to the company
# why do you want to work here and why did you choose to become a medical assistant what personal skills do you have that make you a great ma
# why do you want to work here
# why do i want to work here
# strengthsweaknesses why do you want to work here
# why do you want to work here
# why do you want to work here
# why do you want to work here do you enjoy working with seniors
# why do you want to work here do you enjoy working with seniors
# why do you want to work with us
# why did i want to work there
# why do you want to work for maxim
# why do you want to work for us
# why do you want to work with us
# why do you want to do this job
# why would you want to work here
# why do you want to work here
# Group 12:
# would you say you ’ re a team player
# would you say you ’ re a team player
# Group 13:
# describe a time you had to deal with a difficult patient and how you handled that
# how do you deal with a difficult patient
# describe a time you had to deal with a difficult patient and how you handled that
# Group 14:
# why should we hire you
# basically why should we hire you
# basically why should we hire you
# why should we hire you
# where do you see yourself in 5 years why should we hire you
# where do you see yourself in 5 years why should we hire you
# why should they hire me
# why should they hire me
# why should they hire me
# why should we hire you
# Group 15:
# if you disagree with a physician ’ s approach to treating a patient how do you handle it
# if you disagree with a physician ’ s approach to treating a patient how do you handle it
# Group 16:
# how do you explain complex medical terms and procedures to patients who don ’ t have a healthcare background
# how do you explain complex medical terms and procedures to patients who don ’ t have a healthcare background
# Group 17:
# how do you ensure you remain up to date on advances in nursing
# how do you ensure you remain up to date on advances in nursing
# Group 18:
# when you don ’ t have an answer to a patient ’ s question what do you do
# what do you do when you don ’ t know an answer to a patient ’ s question or how to address a situation
# what do you do when you don ’ t know an answer to a patient ’ s question or how to address a situation
# what do you do when you don ’ t know the answer to something at work—whether it ’ s how to address a situation or answer a patient question—how do you go about getting more information
# when you don ’ t have an answer to a patient ’ s question what do you do
# Group 19:
# describe a time when you were in conflict with a fellow nurse how did you handle the situation
# can you describe how you would resolve a conflict with a fellow nurse or healthcare professional
# describe a time when you were in conflict with a fellow nurse how did you handle the situation
# Group 20:
# what are your responsibilities as a home health aide
# how long have you been working as a home health aide
# what are your responsibilities as a home health aide
# Group 21:
# what would you do if a patients vital signs suddenly dropped
# what are the vital signs
# Group 22:
# can you share an instance when you went above and beyond in caring for someone
# a time you went beyond and above for a patient
# a time you went beyond and above for a patient
# a time when i went above beyond for a patient
# Group 23:
# what do you do if your replacement doesnt arrive on time
# how do you handle a situation where your replacement does not arrive on time
# Group 24:
# how would you handle a difficult patient
# how would you handle a difficult patient
# what would you do if you had a difficult patient
# how do you deal with a difficult patient
# how do you handle difficult patients
# how would you handle an angry patient
# Group 25:
# how would you handle a crisis such as an outbreak
# how would you handle a crisis such as an outbreak
# how would you handle a crisis
# Group 26:
# how would you handle a patient who struggles with pain management
# how would you handle a patient who struggles with pain management
# Group 27:
# how do you respond when people ask for your personal diagnosis outside of a clinical setting
# how do you respond when people ask for your personal diagnosis outside a clinical setting
# Group 28:
# why did you want to be a nurse
# why do you want to be a cna
# why do you want to be cna here
# why do you want to be a cna
# why did you decide to be a nurse
# why did i want to work there
# why do you want to be a medical assistant
# Group 29:
# what type of office administration experience do you have
# what type of clinical experience do you have
# what type of clinical experience do you have
# Group 30:
# have you already been faced with a patient who did not disclose important information how did you manage the situation and what was the outcome
# describe a time you were faced with a patient who chose not to communicate or disclose important information how did you handle the situation and what was the outcome
# Group 31:
# tell me about your experience with a patient who required a lot of your time how did you care for this patient and still provide other patients with adequate care
# describe your experience with a very ill patient who required a lot of your time how did you manage this patient ’ s care while ensuring your other patients were adequately cared for
# describe your experience with a very ill patient who required a lot of your time how did you manage this patient ’ s care while ensuring your other patients were adequately cared for
# Group 32:
# how do you ensure that your patients receive the best possible care
# how do you ensure that your patients receive the best possible care
# Group 33:
# what are your thoughts on the current state of home health care
# what are your thoughts on the current state of home health care
# Group 34:
# what is your experience with caring for elderly or disabled patients
# what is your experience with caring for elderly or disabled patients
# Group 35:
# what are your thoughts on endoflife care
# what are your thoughts on providing personal care to patients
# what are your thoughts on wound care
# what are your thoughts on endoflife care
# what are your thoughts on providing personal care to patients
# what are your thoughts on wound care
# Group 36:
# how do you deal with difficult family dynamics
# how do you deal with a difficult patient
# how do you deal with difficult clients
# how do you deal with difficult family dynamics
# Group 37:
# what are your thoughts on medication management
# what are your thoughts on medication management
# Group 38:
# what are your thoughts on nutrition and diet for home health patients
# what are your thoughts on exercise and physical activity for home health patients
# what are your thoughts on socialization and activities for home health patients
# what are your thoughts on nutrition and diet for home health patients
# what are your thoughts on exercise and physical activity for home health patients
# what are your thoughts on socialization and activities for home health patients
# Group 39:
# what do you like most about being a nurse
# what do you find most rewarding about being a nurse
# what do you find most difficult about being a nurse
# what do you find most difficult about being a nurse how do you overcome this difficulty
# what do you like most about being a nurse
# what do you find most difficult about being a nurse
# what do you find most rewarding about being a nurse
# what do you find most difficult about being a nurse how do you overcome this difficulty
# what did you like about school the most
# what did you like about school the most
# what do you like most about working with the elderly
# what do you find most pleasing about being a nurse
# Group 40:
# what are your strengths and weaknesses as a nurse
# what are your strengths and weaknesses as a nurse
# what are your strengths
# what are your weaknesses
# what are your strengths and weaknesses
# what are your strengths
# what are my strengths
# Group 41:
# why did you choose nursing as your chosen profession
# why did you choose nursing as your chosen profession
# Group 42:
# what do you think are the most important qualities of a successful nurse
# what do you think are the most important qualities of a successful nurse
# what are the most important qualities for a nurse midwife to have
# what do you think is the most important aspect of being a nurse assistant
# what are the most important qualities for a successful home health aide
# Group 43:
# what do you think are the biggest challenges facing nurses today
# what do you think are the biggest challenges facing nurses today
# Group 44:
# how do you explain medications treatments or healthcare situations without using a lot of medical or healthcare jargon
# how do you explain medications treatments or healthcare situations without using a lot of medical or healthcare jargon
# can you explain situations without using a lot of medical jargon give an example
# Group 45:
# describe a time a patient was really happy with your care or a time you went above and beyond for a patient
# describe a time you went above and beyond for a patient or customer describe a time you needed help with your duties how did you approach the situation describe a time you had to deal with a problem at work how did you handle it
# a time you went beyond and above for a patient
# a time you went beyond and above for a patient
# a time when i went above beyond for a patient
# Group 46:
# describe a situation when you had to work with a difficult coworker what was the problem and how did you resolve it
# describe a situation when you had to work closely with a difficult coworker how did you handle the situation were you able to build a relationship with this person
# Group 47:
# how do you handle changes to your assignment the unit schedule etc
# how do you handle changes to your assignment the unit schedule etc
# Group 48:
# describe a time you were under a lot of pressure how did you handle it
# tell me about a time you were under a lot of pressure what was going on and how did you get through it
# Group 49:
# how would you handle a disagreement with a doctor
# how would you handle a disagreement with a nurse or doctor
# Group 50:
# describe a time when you were particularly proud of your healthcare team what was your role in this situation
# describe a situation where you felt proud of your healthcare team what role did you play in your team ’ s success
# Group 51:
# tell me about a time when a patient ’ s family was dissatisfied with your care how did you handle that situation
# tell me about a time when you had to do something difficult how did you handle that
# Group 52:
# describe a time you provided effective patient or family education
# what is your idea of effective patient and family education
# Group 53:
# talk about a time a patient or their family was particularly pleased and appreciative of your care
# talk about a time a patient or their family was particularly pleased and appreciative of your care
# Group 54:
# describe a time when your facility was undergoing some change how did that impact you and how did you adapt
# describe a time when your facility was undergoing some change how did that impact you and how did you adapt
# Group 55:
# tell me about a time when you didn ’ t know the answer to something at work how did you go about finding the information
# what do you do when you don ’ t know the answer to something at work—whether it ’ s how to address a situation or answer a patient question—how do you go about getting more information
# tell me about a time when you didn ’ t know the answer to something at work how did you go about finding the information
# Group 56:
# give me an example of an awkward situation at work how did you remove yourself from the situation
# give me an example of an awkward situation at work how did you remove yourself from the situation
# Group 57:
# tell me about a time you failed how did you deal with this situation
# tell me about a time you failed how did you deal with this situation
# Group 58:
# describe a time when you anticipated potential problems with a patient and initiated preventative measures
# describe a time when you anticipated potential problems with a patient and initiated preventative measures
# Group 59:
# talk about a time you worked in a fastpaced setting how do you prioritize tasks while maintaining excellent patient care
# talk about a time you worked in a fastpaced setting how do you prioritize tasks while maintaining excellent patient care
# Group 60:
# give an example of an important goal you set for yourself did you accomplish that goal how did you ensure that you accomplished it
# give an example of an important goal you set for yourself did you accomplish that goal how did you ensure that you accomplished it
# Group 61:
# give an example of a time when you were able to successfully persuade a patient to agree to something how did you persuade this person
# give an example of a time when you were able to successfully persuade a patient to agree to something how did you persuade this person
# Group 62:
# tell me about a time when you had to rely on written communication to explain yourself to your team or to a patient
# tell me about a time when you had to rely on written communication to explain yourself to your team or to a patient
# Group 63:
# talk about a time when you had not communicated well how did you correct the situation
# talk about a time when you had not communicated well how did you correct the situation
# Group 64:
# describe a time when you received negative feedback and turned it into something positive
# describe a time when you received negative feedback and turned it into something positive
# Group 65:
# what is one professional accomplishment that you are most proud of and why
# what is one professional accomplishment that you are most proud of and why
# Group 66:
# have you ever felt dissatisfied with your work as a nurse what could have been done to make it better
# have you ever felt dissatisfied with your work as a nurse what could have been done to make it better
# Group 67:
# describe a time when you went over and above your job requirements what motivated you to put forth the extra effort
# describe a time when you went over and above your job requirements what motivated you to put forth the extra effort
# Group 68:
# give an example of a mistake you ’ ve made how did you handle it
# give an example of a mistake you ’ ve made how did you handle it
# Group 69:
# what makes you stand out from other nurse midwives
# what makes you stand out from the other applicants
# Group 70:
# what do you think is the most important thing for a patient to know about their care
# what do you think is the most important part of providing personalized care to a patient
# Group 71:
# how would you handle a hostile situation with a resident or a coworker
# how would you handle a hostile situation with a resident or a coworker
# Group 72:
# ok to work with covid19 patients
# ok to work with covid19 patients
# Group 73:
# they asked me what i knew about the facility
# they asked me what i knew about the facility
# Group 74:
# why did you decide to apply to our hospital or medical center
# why did you decide to choose to apply to wellstar
# why did you decide to choose to apply to wellstar
# why did you decide to choose to apply to wellstar
# Group 75:
# how do you get along with others
# how do you get along with others
# Group 76:
# where do you see yourself in 5 years
# where do you see myself in 5 years
# where do you see yourself in 2 years
# what are your goals where do you see yourself in 5 years in the nursing profession
# where do you see yourself in five years
# where do you see yourself in 5 years why should we hire you
# where do you see yourself in 5 years why should we hire you
# where do you see yourself in 5 years
# where do you see yourself in 5 years
# where do you see yourself in 5 years
# where do you see yourself in 5 years
# where do i see myself in 5 years
# what do you see yourself doing in the next 5 years
# where do you see yourself in the next upcoming years professionally
# Group 77:
# how long as a certified nurse aide
# how long as a certified nurse aide
# are you certified as a nurse assistant
# how long have you been working as a home health aide
# Group 78:
# what is the duty of a certified nursing assistant
# what is the duty of a certified nursing assistant
# Group 79:
# if someone was a dnr and they stop breathing how would you react
# if someone was a dnr and they stop breathing how would you react
# Group 80:
# what would make you a good candidate for the job
# what would make you a good candidate for the job
# what makes you a good candidate
# what makes you a good candidate
# why i felt i was a good candidate for the job
# why i felt i was a good candidate for the job
# Group 81:
# are you okay with this type of work
# are you okay with this type of work
# what type of experience do you have and with what type of patients are you cpr certified what type of patient are you comfortable working with why do you like being a home health aide
# Group 82:
# how attached are you to your fake nails
# how attached are you to your fake nails
# Group 83:
# describe your past experiences
# past experiences
# Group 84:
# have you had a a dnr patient before
# have you had a a dnr patient before
# Group 85:
# what unit do you prefer to work on
# what unit do you prefer to work on
# Group 86:
# i can see that you applied to many positions why are you interested in this one
# i can see that you applied to many positions why are you interested in this one
# Group 87:
# why do you want to work in long term care
# why do you want to work in health care
# Group 88:
# why do you wan na work at parkway
# why do you wan na work for us
# Group 89:
# are you reliable
# do you have reliable transportation
# Group 90:
# why did i become a cna
# what made you become a cna
# why did i become a nursing assistant
# Group 91:
# when can you start
# when could i start working
# when can you start
# when can you start what shift are you able to work
# when can you start
# when can you start
# when is the earliest can you start
# they when can i start
# they when can i start
# when i could start
# when can you start
# Group 92:
# what are my strength and weaknesses
# what are your weaknesses
# what are your strengths and weaknesses
# Group 93:
# how to you interact with your coworkers in stressful situations
# how do you handle stressful situations
# how do you react in stressful situations
# Group 94:
# how many years experience i have
# how many years have i done this kind of work
# how many years of experience do i have in healthcare
# how many years of experience in medical field
# how many years of experience in medical field
# why do i want to teach medical assisting how many years experience do you have
# how many years of caregiving experience do you have
# how many years of caregiving experience do you have
# how many years of experience
# years of experience
# Group 95:
# what is your experience like
# what is your experience
# what is your experience
# Group 96:
# what is one of your weaknesses
# what are your weaknesses
# what is one of your weakness at work
# what is one of your weakness at work
# what is one of your weakness at work
# can you tell me one of your weaknesses
# can you tell me one of your weaknesses
# can you tell me one of your weaknesses
# what is one of your weaknesses
# what is one weakness
# Group 97:
# what hours are you available
# what hours am i available
# what hours are you available
# when are you available
# Group 98:
# tell me a little bit about yourself where have you worked what are your expectations
# tell me a bit about yourself
# tell me a little about yourself
# Group 99:
# i was asked about my experience and what i want out of a position
# they asked about my experience
# they asked about my experience
# Group 100:
# how did you deal with a difficult coworker
# how do you deal with a difficult patient
# what did you do when dealing with a difficult coworker
# what did you do when dealing with a difficult coworker
# basic questions how did you deal with a difficult manager
# how do you deal with difficult clients
# Group 101:
# they asked about my experience in working on a team
# they asked about my experience
# they asked about my experience
# Group 102:
# how soon are you available for work
# when are you available
# Group 103:
# why are you a good fit for this position
# why are u applying for this position
# why do you think you would be a good fit for fhc
# why do you think youd be a good fit for this job
# Group 104:
# why did i want to work for their company
# why do you want to work for us
# why did i want to work for them
# why do you want to work for us
# why i chose their company
# why did i want to work there
# why do you want to work for us
# Group 105:
# what do you see yourself doing five years from now
# where do you see yourself in five years
# what do you see yourself doing in the next 5 years
# Group 106:
# what your qualifications as a cna
# what are your qualifications as a nurse assistant
# Group 107:
# what is your goal working here
# what is your long time career goal
# what is your long time career goal
# Group 108:
# how long have you work as a nursing assistant
# how long have you worked as a cna
# how long have you been a medical assistant
# how long have you been a medical assistant
# how long have you been a medical assistant
# Group 109:
# what do you think is the most important aspect of company culture
# what do you think is the most important aspect of being a nurse assistant
# Group 110:
# why do you want to work at sutter health
# why do you want to work in health care
# why do you want to work at our health facility
# Group 111:
# tell us about your experience
# tell us a little about yourself
# Group 112:
# how long was you a cna
# how long have you worked as a cna
# how long was i doing this
# Group 113:
# why are you interested in patient care
# why are you interested in medicine
# Group 114:
# what experience do you have
# do you have any prior experience
# do you have any prior experience
# do you have any prior experience
# what type of clinical experience do you have
# what type of clinical experience do you have
# experience
# how much experience do you have
# did i have experience
# do you have experience
# what experience do you have with medical technology
# Group 115:
# what are some of your strengths
# what are your strengths
# what are your strengths and weaknesses
# what are your strengths
# what are my strengths
# what are some of your achievements
# Group 116:
# job experience
# experience
# Group 117:
# they asked me when i could start
# when could i start working
# they when can i start
# they when can i start
# when i could start
# Group 118:
# what is your availability l
# availability to work
# availability to work
# what is my availability and times
# what is your experience
# what is your experience
# Group 119:
# what role do you play when working with a team
# describe a situation where you felt proud of your healthcare team what role did you play in your team ’ s success
# how do you like working with a team
# Group 120:
# about my experience and why i wanted to work there
# why do u want to work there
# why o wanted to work for them
# why o wanted to work for them
# why did i want to work there
# why i wanted to work for them
# Group 121:
# why did you decide to apply to bellin health
# why did you decide to be a nurse
# why did you decide to choose to apply to wellstar
# why did you decide to choose to apply to wellstar
# why did you decide to choose to apply to wellstar
# Group 122:
# the asked about myself and very forward with how much they pay
# how much do they pay and what are the benefits
# Group 123:
# what do you do when you first enter a patient ’ s room
# what do you do when entering a patient ’ s room
# Group 124:
# what is a cna responsible for
# what is a cna responsible for
# Group 125:
# what are your career goals
# what are your professional goals
# Group 126:
# as a cna what sets you apart from others
# as a cna what do you bring to the company that sets you apart from others
# Group 127:
# do you have any questions about the position or company
# do you have any questions
# do you have any questions for us
# Group 128:
# tell us about a time when you had to do something difficult how did you handle that and how can that help you as a cna
# tell me about a time when you had to do something difficult how did you handle that
# Group 129:
# what motivated you to become a nursing assistant
# why did i become a nursing assistant
# Group 130:
# what is was looking for in a job
# what is was looking for in a job
# Group 131:
# normal basic questions
# normal basic questions
# Group 132:
# how long have i worked in the field
# how long have you worked as a cna
# how long i worked in healthcare
# how long i worked in healthcare
# how long have i worked in the field
# Group 133:
# just asked about your background in the position
# just asked about your background in the position
# Group 134:
# can you draw blood no other questions regarding my training physicians id worked with nor about my 25 years of medical assisting skills etc
# can you draw blood no other questions regarding my training physicians id worked with nor about my 25 years of medical assisting skills etc
# Group 135:
# what are some of your strong points in the work place
# what are some of your strong points in the work place
# Group 136:
# how good are you at multitasking
# how good are you at multitasking
# Group 137:
# have you ever worked from home or online before
# have you ever worked from home or online before
# have you ever worked from home or online before
# have you ever worked from home or online before
# have you ever worked for us before
# have you ever worked for us before
# Group 138:
# describe your experience
# describe your experience
# describe your experience
# experience
# what is your experience
# what is your experience
# Group 139:
# if i can handle bloody situations and open wounds
# if i can handle bloody situations and open wounds
# if i can handle bloody situations and open wounds
# Group 140:
# are you willing to do things beyond your job description to help the familybusiness
# are you willing to do things beyond your job description to help the familybusiness
# are you willing to do things beyond your job description to help the familybusiness
# Group 141:
# what would be your biggest challenge what do you do with a conflict between a coworker how do you respond to high stress environment what is a weakness of yours what is a strength how would you deal with a coworker acting in an unsafe manner with a patient
# what would be your biggest challenge what do you do with a conflict between a coworker how do you respond to high stress environment what is a weakness of yours what is a strength how would you deal with a coworker acting in an unsafe manner with a patient
# what would be your biggest challenge what do you do with a conflict between a coworker how do you respond to high stress environment what is a weakness of yours what is a strength how would you deal with a coworker acting in an unsafe manner with a patient
# Group 142:
# where are ekg leads placed not the exact question but pretty close
# where are ekg leads placed not the exact question but pretty close
# where are ekg leads placed not the exact question but pretty close
# Group 143:
# are you available to work 12hr shifts and possible overtime
# are you available to work 12hr shifts and possible overtime
# are you available to work 12hr shifts and possible overtime
# Group 144:
# what attracted you to this job
# what attracted you to this job
# what attracted you to this job
# Group 145:
# what is your background as a medical assistant and skills with pediatrics
# what is your background as a medical assistant and skills with pediatrics
# what is your background as a medical assistant and skills with pediatrics
# Group 146:
# what made me consider this company
# what made me consider this company
# what made me consider this company
# Group 147:
# tell me about a time when you had to deal with a coworker that was hostile
# tell me about a time when you had to do something difficult how did you handle that
# tell me about a time when you had to deal with a coworker that was hostile
# tell me about a time when you had to deal with a coworker that was hostile
# Group 148:
# do i consider myself more of an extrovertintrovert
# do i consider myself more of an extrovertintrovert
# Group 149:
# how many times were you late for work in the past year
# how many times were you late for work in the past year
# Group 150:
# tell me a time when you had a argument with a boss
# tell me a time when you had a argument with a boss
# Group 151:
# what made you leave your previous job
# what made you leave your previous job
# why did you leave your last job
# why did you leave your last job
# Group 152:
# something positive and negative about myself
# something positive and negative about myself
# Group 153:
# what do you know about this company
# what do you know about this company
# what do you know about the role
# what do you know about the role
# what do you know about the company
# Group 154:
# how would your friends describe you
# how would your friends describe you
# Group 155:
# tell us of a time from work where you know you were right but your supervisor asked you to do something different
# tell us of a time from work where you know you were right but your supervisor asked you to do something different
# Group 156:
# given a set of images that represent cross sectional slices of a 3d series representing the heart how would you calculate the internal volume
# given a set of images that represent cross sectional slices of a 3d series representing the heart how would you calculate the internal volume
# Group 157:
# describe yourself
# describe yourself
# Group 158:
# what is the goal or goals you have when treating patients
# what is the goal or goals you have when treating patients
# Group 159:
# what is your best quality for this job
# what is your best quality for this job
# Group 160:
# aptitude testing
# aptitude testing
# Group 161:
# he just started talking about himself
# he just started talking about himself
# Group 162:
# how did you handle conflict at your last place of employment
# how did you handle conflict at your last place of employment
# Group 163:
# do you speak any other languages
# do you speak any other languages
# Group 164:
# do you have your certification
# do you have your certification
# Group 165:
# why do you want to teach
# why do you want to teach
# why do i want to teach medical assisting how many years experience do you have
# why do you want to do this job
# Group 166:
# why i was choosing dermatology and cosmetic surgery
# why i was choosing dermatology and cosmetic surgery
# Group 167:
# do you have children
# do you have children
# do you have children
# do you have children
# tell us about yourself do you have any children
# do you have children
# Group 168:
# was i able to work with more then 2 doctor s at a time
# was i able to work with more then 2 doctor s at a time
# Group 169:
# how many patients would you consider a lot
# how many patients would you consider a lot
# Group 170:
# how do you feel about old people
# how do you feel about old people
# how old are you
# Group 171:
# i was asked by two members of the management team how old i was i did not expect to be asked about my age and felt the questioning should have been directed toward my experience and education the management team could have easily assessed my age by the background check or made a best guess by my resume
# i was asked by two members of the management team how old i was i did not expect to be asked about my age and felt the questioning should have been directed toward my experience and education the management team could have easily assessed my age by the background check or made a best guess by my resume
# Group 172:
# regular questions
# regular questions
# Group 173:
# how far away from the office to you stay
# how far away from the office to you stay
# Group 174:
# are any of my family members sick
# are any of my family members sick
# Group 175:
# what do you do in your spare time at work
# what do you do in your spare time at work
# Group 176:
# are you a certified medical assistant
# are you certified as a nurse assistant
# are you a certified medical assistant
# Group 177:
# why i was looking to leave my current employer
# why i was looking to leave my current employer
# why did you leave your last employer
# Group 178:
# how do you interact in a team environment
# how do you interact in a team environment
# Group 179:
# how would i deal with a situation that has occurred differently
# how would i deal with a situation that has occurred differently
# Group 180:
# when you wake up in the morning and look at yourself in the mirror what do you see
# when you wake up in the morning and look at yourself in the mirror what do you see
# Group 181:
# do you think its fair to treat every patient the same
# do you think its fair to treat every patient the same
# Group 182:
# why would you like to work at scripps
# why would you like to work at scripps
# Group 183:
# what is your weakness
# what is one of your weakness at work
# what is one of your weakness at work
# what is one of your weakness at work
# what is your weakness
# what is your experience
# what is one weakness
# what is your experience
# Group 184:
# how many days are u open
# how many days are u open
# Group 185:
# what made you choose medstar
# what made you choose medstar
# Group 186:
# would you like to further your education
# would you like to further your education
# Group 187:
# what would you do if you had a problem student in your class
# what would you do if you had a problem student in your class
# Group 188:
# do you speak spanish
# do you speak spanish
# the most difficult question was being asked if i speak spanish
# Group 189:
# do you have a phlebotomy certificate
# do you have a phlebotomy certificate
# Group 190:
# do u have a drivers license and reliable transportation
# do u have a drivers license and reliable transportation
# do you have reliable transportation
# Group 191:
# how much did they think i would be comfortable accepting as a wage hourly
# how much did they think i would be comfortable accepting as a wage hourly
# Group 192:
# do you work well with others
# do you work well with others
# Group 193:
# if your last supervisor would say something negative about you what would it be
# if your last supervisor would say something negative about you what would it be
# Group 194:
# can you work 50 hours plus a week
# how many hours can you work per week
# Group 195:
# how would you deal with a difficult patient in regards to insurance
# how do you deal with a difficult patient
# Group 196:
# how do you like working in the medical field
# how do you like working with a team
# how many years of experience in medical field
# how many years of experience in medical field
# how do you like working with elderly
# how do you like working with elderly
# Group 197:
# they asked about my experience with a certain software
# they asked about my experience
# they asked about my experience
# Group 198:
# my experience in health care
# why do you want to work in health care
# Group 199:
# what would you do if you had an angry patient yelling at you
# what would you do if you had a difficult patient
# how would you handle an angry patient
# Group 200:
# mainly about your personal experience
# personal
# Group 201:
# why should they hire me when i have been out of the field for a few years
# why should they hire me
# why should they hire me
# why should they hire me
# Group 202:
# expectation
# they ask about the salary expectation
# Group 203:
# my years of experience
# how many years of experience
# years of experience
# Group 204:
# what can i bring to the company
# what qualities and skills did i have why do j want to work here what could i bring to the company
# what can i bring to the company
# what can you tell me about the company
# Group 205:
# typical why did you leave your last job
# why did you leave your last job
# why did you leave your last job
# why did you leave your last employer
# Group 206:
# introduce yourself what is your expected wage when can you work this is a casual position if your ok with it
# what is expected wage
# Group 207:
# how would you deal with a rude patient
# how do you deal with a difficult patient
# Group 208:
# do you have experience with hoyer lifts or quadriplegic care
# do you have experience with hoyer lifts or quadriplegic care
# Group 209:
# they wanted to copy my social security card and drivers license before the interview
# they wanted to copy my social security card and drivers license before the interview
# Group 210:
# how do you handle a client being angry at you or taking their anger out on you
# how do you handle a client being angry at you or taking their anger out on you
# Group 211:
# if i knew how to transfer patients
# if i knew how to transfer patients
# Group 212:
# describe a problem you ran in in your previous or current job what did you do to solve the problem and how did you feel at the end
# describe a problem you ran in in your previous or current job what did you do to solve the problem and how did you feel at the end
# Group 213:
# since i was a preferred worker they wanted to know who i would be the caregiver for
# since i was a preferred worker they wanted to know who i would be the caregiver for
# Group 214:
# have you worked directly with people before if so to what capacity
# have you worked with elderly people before
# Group 215:
# what was my experience in the field
# i was asked about experience in the field
# Group 216:
# where do you live
# where do you live
# Group 217:
# why did i want this job
# do you want the job
# why do you want to do this job
# Group 218:
# what kind of job are you interested in what would you have the most trouble with what would your reference say about you what are your strengths
# what are your strengths
# what are your strengths
# Group 219:
# if i was certified
# was i certified
# Group 220:
# why do i want to be a home health aidecaregivercompanion
# why i wanted to be a home health aide
# tell us why you want to be a home health aid
# Group 221:
# do you have any experience working with elderly or dementia clients
# do you have any experience working with the elderly
# Group 222:
# what would your former employer say about you if we called them right now
# what would your former employer say about you if we called them right now
# Group 223:
# what are your work experience
# experience
# what is your experience
# what is your experience
# Group 224:
# why do i like what i do
# why do i like what i do
# Group 225:
# why did you want to become a home health aide
# why i wanted to be a home health aide
# what made you choose to become a home health aide
# Group 226:
# what do you think makes a good medical assistant
# what makes you a good candidate
# what makes you a good candidate

# %%
# Create a new 'labels' column in the DataFrame to hold group numbers
cleaned_df['labels'] = None

# Assign group numbers to the 'labels' column
for i, group in enumerate(grouped_questions, start=1):
    cleaned_df.loc[group, 'labels'] = i

# show the modified DataFrame
cleaned_df
# Out:
#                    Topic           Job Role  \
# 0     Nursing Assistants              Nurse
# 1     Nursing Assistants              Nurse
# 2     Nursing Assistants              Nurse
# 3     Nursing Assistants              Nurse
# 4     Nursing Assistants              Nurse
# ...                  ...                ...
# 1045   Medical Assistant  Medical Assistant
# 1046   Medical Assistant  Medical Assistant
# 1047   Medical Assistant  Medical Assistant
# 1048   Medical Assistant  Medical Assistant
# 1049   Medical Assistant  Medical Assistant
#
#                                               Questions  \
# 0             why did you decide on a career as a nurse
# 1             what do you find rewarding about this job
# 2     how do you deal with someone who isn ’ t satis...
# 3     tell me what you feel your greatest skill as a...
# 4               how do you handle the stress of the job
# ...                                                 ...
# 1045  tell me about your previous experience as a me...
# 1046   what do you think makes a good medical assistant
# 1047  describe a time when you solved a problem invo...
# 1048  what experience do you have with medical techn...
# 1049  how familiar are you with hipaa protocol and h...
#
#                                                 Answers labels
# 0     I come from a long line of nurses. Both my gra...      1
# 1     I truly love helping people, and when those pe...      2
# 2     While I constantly strive to do everything I c...      3
# 3     I’m very proud of my ability to really listen ...      4
# 4     I find the best way to handle the stress of th...      5
# ...                                                 ...    ...
# 1045  I have worked in a hospital setting for the pa...   None
# 1046  From my experience, empathy is one of the key ...    226
# 1047  The most challenging situation I experienced a...   None
# 1048  When I first entered the medical assistant fie...    114
# 1049  From what I understand, HIPAA is a federal law...   None
#
# [1050 rows x 5 columns]

# %%
cleaned_df.labels.nunique()
# Out:
# 226

# %%
## sort the dataframe according to the group numbers
cleaned_df.sort_values(by='labels', inplace=True)
cleaned_df
# Out:
#                    Topic           Job Role  \
# 0     Nursing Assistants              Nurse
# 1009  Nursing Assistants              Nurse
# 1     Nursing Assistants              Nurse
# 1010  Nursing Assistants              Nurse
# 2     Nursing Assistants              Nurse
# ...                  ...                ...
# 1042  Nursing Assistants              Nurse
# 1043  Nursing Assistants              Nurse
# 1045   Medical Assistant  Medical Assistant
# 1047   Medical Assistant  Medical Assistant
# 1049   Medical Assistant  Medical Assistant
#
#                                               Questions  \
# 0             why did you decide on a career as a nurse
# 1009          why did you decide on a career as a nurse
# 1             what do you find rewarding about this job
# 1010          what do you find rewarding about this job
# 2     how do you deal with someone who isn ’ t satis...
# ...                                                 ...
# 1042  how do you use organizational skills in your d...
# 1043  which factors give out as a motivation for you...
# 1045  tell me about your previous experience as a me...
# 1047  describe a time when you solved a problem invo...
# 1049  how familiar are you with hipaa protocol and h...
#
#                                                 Answers labels
# 0     I come from a long line of nurses. Both my gra...      1
# 1009  I come from a long line of nurses. Both my gra...      1
# 1     I truly love helping people, and when those pe...      2
# 1010  I truly love helping people, and when those pe...      2
# 2     While I constantly strive to do everything I c...      3
# ...                                                 ...    ...
# 1042  Being as a nurse, I’m enrolled with various re...   None
# 1043  The admiration from my patients, seniors and t...   None
# 1045  I have worked in a hospital setting for the pa...   None
# 1047  The most challenging situation I experienced a...   None
# 1049  From what I understand, HIPAA is a federal law...   None
#
# [1050 rows x 5 columns]

# %%
cleaned_df.to_csv('healthcare_labelled_dataset.csv', index=False)

# %%
grouped_df = pd.read_csv('/content/healthcare_labelled_dataset.csv')

# %%
grouped_df
# Out:
#                    Topic           Job Role  \
# 0     Nursing Assistants              Nurse
# 1     Nursing Assistants              Nurse
# 2     Nursing Assistants              Nurse
# 3     Nursing Assistants              Nurse
# 4     Nursing Assistants              Nurse
# ...                  ...                ...
# 1045  Nursing Assistants              Nurse
# 1046  Nursing Assistants              Nurse
# 1047   Medical Assistant  Medical Assistant
# 1048   Medical Assistant  Medical Assistant
# 1049   Medical Assistant  Medical Assistant
#
#                                               Questions  \
# 0             why did you decide on a career as a nurse
# 1             why did you decide on a career as a nurse
# 2             what do you find rewarding about this job
# 3             what do you find rewarding about this job
# 4     how do you deal with someone who isn ’ t satis...
# ...                                                 ...
# 1045  how do you use organizational skills in your d...
# 1046  which factors give out as a motivation for you...
# 1047  tell me about your previous experience as a me...
# 1048  describe a time when you solved a problem invo...
# 1049  how familiar are you with hipaa protocol and h...
#
#                                                 Answers  labels
# 0     I come from a long line of nurses. Both my gra...     1.0
# 1     I come from a long line of nurses. Both my gra...     1.0
# 2     I truly love helping people, and when those pe...     2.0
# 3     I truly love helping people, and when those pe...     2.0
# 4     While I constantly strive to do everything I c...     3.0
# ...                                                 ...     ...
# 1045  Being as a nurse, I’m enrolled with various re...     NaN
# 1046  The admiration from my patients, seniors and t...     NaN
# 1047  I have worked in a hospital setting for the pa...     NaN
# 1048  The most challenging situation I experienced a...     NaN
# 1049  From what I understand, HIPAA is a federal law...     NaN
#
# [1050 rows x 5 columns]

# %%
grouped_df.columns
# Out:
# Index(['Topic', 'Job Role', 'Questions', 'Answers', 'labels'], dtype='object')

# %%
grouped_df['Job Role'].unique()
# Out:
# array(['Nurse', 'Nursing', 'Home Health Aide', 'Medical Assistant', 'All',
#        'Midwife', 'Personal care Assistant', 'Medical assistant',
#        'Nurse and Midwife'], dtype=object)

# %%
grouped_df['Topic'].unique()
# Out:
# array(['Nursing Assistants', 'Nursing assistant', 'Home Health Aide',
#        'Problem-solving skills', 'Behavioral Question',
#        'Medical Assistant', 'General', 'nursing assistant',
#        'Nursing, Situational Questions',
#        'Home Health and Personal Care Aides',
#        'Nursing, Behavioral Question', 'Expertise question',
#        'Nursing Assistant', 'Medical Assistants',
#        'Personality and Character Nursing Interview Question',
#        'Educational Background Nursing Interview Question',
#        'Questions About Work Experience',
#        'Choice About Being a Nurse - Nursing Interview Question',
#        'Questions To Assess Critical Thinking',
#        'Diversity and Cultural Competency'], dtype=object)
